# %%
# Create a scene with a house, a tree, and a sun
# Based on the picture at http://dragonometry.net/blog/?p=566

import turtle
import math

# Set the background color
screen = turtle.Screen()
screen.bgcolor("skyblue")

# Create our turtle
george = turtle.Turtle()
george.color("black")
george.shape("turtle")
george.speed(10)

# Define a funtion to draw and fill a rectangle with the given
# dimensions and color
def drawRectangle(t, width, height, color):
  t.fillcolor(color)
  t.begin_fill()
  t.forward(width)
  t.left(90)
  t.forward(height)
  t.left(90)
  t.forward(width)
  t.left(90)
  t.forward(height)
  t.left(90)
  t.end_fill()
  
# Define a function to draw and fill an equalateral right 
# triangle with the given hypotenuse length and color.  This
# is used to create a roof shape.
def drawTriangle(t, length, color):
  t.fillcolor(color)
  t.begin_fill()
  t.forward(length)
  t.left(135)
  t.forward(length / math.sqrt(2))
  t.left(90)
  t.forward(length / math.sqrt(2))
  t.left(135)
  t.end_fill()
  
# Define a function to draw and fill a parallelogram, used to
# draw the side of the house
def drawParallelogram(t, width, height, color):
  t.fillcolor(color)
  t.begin_fill()
  t.left(30)
  t.forward(width)
  t.left(60)
  t.forward(height)
  t.left(120)
  t.forward(width)
  t.left(60)
  t.forward(height)
  t.left(90)
  t.end_fill()
  
# Define a function to draw four sun rays of the given length,
# for the sun of the given radius.  The turtle starts in the 
# center of the circle.
def drawFourRays(t, length, radius):
  for i in range(4):
    t.penup()
    t.forward(radius)
    t.pendown()
    t.forward(length)
    t.penup()
    t.backward(length + radius)
    t.left(90)

# Draw and fill the front of the house
george.penup() 
george.goto(-150, -120)
george.pendown()
drawRectangle(george, 100, 110, "blue")

# Draw and fill the front door
george.penup()
george.goto(-120, -120)
george.pendown()
drawRectangle(george, 40, 60, "lightgreen")

# Front roof
george.penup()
george.goto(-150, -10)
george.pendown()
drawTriangle(george, 100, "magenta")

# Side of the house
george.penup()
george.goto(-50, -120)
george.pendown()
drawParallelogram(george, 60, 110, "yellow")

# Window
george.penup()
george.goto(-30, -60)
george.pendown()
drawParallelogram(george, 20, 30, "brown")

# Side roof
george.penup()
george.goto(-50, -10)
george.pendown()
george.fillcolor("orange")
george.begin_fill()
george.left(30)
george.forward(60)
george.left(105)
george.forward(100 / math.sqrt(2))
george.left(75)
george.forward(60)
george.left(105)
george.forward(100 / math.sqrt(2))
george.left(45)
george.end_fill()

# Tree base
george.penup() 
george.goto(100, -130)
george.pendown()
drawRectangle(george, 20, 40, "brown")

# Tree top
george.penup() 
george.goto(65, -90)
george.pendown()
drawTriangle(george, 90, "lightgreen")
george.penup() 
george.goto(70, -45)
george.pendown()
drawTriangle(george, 80, "lightgreen")
george.penup() 
george.goto(75, -5)
george.pendown()
drawTriangle(george, 70, "lightgreen")

# Sun
george.penup() 
george.goto(55, 110)
george.fillcolor("yellow")
george.pendown()
george.begin_fill()
george.circle(24)
george.end_fill()

# Sun rays
george.penup()
george.goto(55, 134)
george.pendown()
drawFourRays(george, 25, 24)
george.right(45)
drawFourRays(george, 15, 24)
george.left(45)

# Put down some labels
george.color("black")
george.penup()
george.goto(-150, 70)
george.pendown()
george.write("House", None, None, "14pt bold")
george.penup()
george.goto(150, -150)
george.pendown()
george.write("Tree", None, None, "14pt bold")
george.penup()
george.goto(130, 150)
george.pendown()
george.write("Sun", None, None, "14pt bold")

# Bring the turtle down to the front door, and we're done!
george.penup()
george.goto(-100, -150)
george.left(90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-983928e61870> in <module>
#     163 george.goto(-150, 70)
#     164 george.pendown()
# --> 165 george.write("House", None, None, "14pt bold")
#     166 george.penup()
#     167 george.goto(150, -150)
#
# C:\conda\lib\turtle.py in write(self, arg, move, align, font)
#    3429             self.undobuffer.push(["seq"])
#    3430             self.undobuffer.cumulate = True
# -> 3431         end = self._write(str(arg), align.lower(), font)
#    3432         if move:
#    3433             x, y = self.pos()
#
# AttributeError: 'NoneType' object has no attribute 'lower'

# %%
# Create a scene with a tree, house and sun
# Based on the picture at http://dragonometry.net/blog/?p=566

import turtle
import math

# Set the background color
screen = turtle.Screen()
screen.bgcolor("skyblue")

# Create our turtle
house = turtle.Turtle()
house.color("black")
house.shape("turtle")
house.speed(10)

# Define a funtion to draw and fill a rectangle with the given
# dimensions and color
def drawRectangle(tk, width, height, color):
  tk.fillcolor(color)
  tk.begin_fill()
  tk.forward(width)
  tk.left(90)
  tk.forward(height)
  tk.left(90)
  tk.forward(width)
  tk.left(90)
  tk.forward(height)
  tk.left(90)
  tk.end_fill()
  
# Define a function to draw and fill an equalateral right 
# triangle with the given hypotenuse length and color.  This
# is used to create a roof shape.
def drawTriangle(tk, length, color):
  tk.fillcolor(color)
  tk.begin_fill()
  tk.forward(length)
  tk.left(135)
  tk.forward(length / math.sqrt(2))
  tk.left(90)
  tk.forward(length / math.sqrt(2))
  tk.left(135)
  tk.end_fill()
  
# Define a function to draw and fill a parallelogram, used to
# draw the side of the house
def drawParallelogram(tk, width, height, color):
  tk.fillcolor(color)
  tk.begin_fill()
  tk.left(30)
  tk.forward(width)
  tk.left(60)
  tk.forward(height)
  tk.left(120)
  tk.forward(width)
  tk.left(60)
  tk.forward(height)
  tk.left(90)
  tk.end_fill()
  
# Define a function to draw four sun rays of the given length,
# for the sun of the given radius.  The turtle starts in the 
# center of the circle.
def drawFourRays(k, length, radius):
  for i in range(4):
    k.penup()
    k.forward(radius)
    k.pendown()
    k.forward(length)
    k.penup()
    k.backward(length + radius)
    k.left(90)
    
def writeText(tk):
    #k.end_fill() 
    #tk.setposition(width, height)
    text="This is my Final Drawing"
    tk.color('deep pink')
    style = ('Courier', 30, 'italic')
    turtle.write(text, font=style, align='top')

#Draw text on top of turtle 
house.penup()
house.goto(-120, -130)
house.pendown()
writeText(house)

# Draw and fill the front of the house
house.penup() 
house.goto(-150, -120)
house.pendown()
drawRectangle(house, 100, 110, "blue")

# Draw and fill the front door
house.penup()
house.goto(-120, -120)
house.pendown()
drawRectangle(house, 40, 60, "lightgreen")

# Front roof
house.penup()
house.goto(-150, -10)
house.pendown()
drawTriangle(house, 100, "magenta")

# Side of the house
house.penup()
house.goto(-50, -120)
house.pendown()
drawParallelogram(house, 60, 110, "yellow")

# Window
house.penup()
house.goto(-30, -60)
house.pendown()
drawParallelogram(house, 20, 30, "brown")

# Side roof
house.penup()
house.goto(-50, -10)
house.pendown()
house.fillcolor("orange")
house.begin_fill()
house.left(30)
house.forward(60)
house.left(105)
house.forward(100 / math.sqrt(2))
house.left(75)
house.forward(60)
house.left(105)
house.forward(100 / math.sqrt(2))
house.left(45)
house.end_fill()

# Tree base
house.penup() 
house.goto(100, -130)
house.pendown()
drawRectangle(house, 20, 40, "brown")

# Tree top
house.penup() 
house.goto(65, -90)
house.pendown()
drawTriangle(house, 90, "lightgreen")
house.penup() 
house.goto(70, -45)
house.pendown()
drawTriangle(house, 80, "lightgreen")
house.penup() 
house.goto(75, -5)
house.pendown()
drawTriangle(house, 70, "lightgreen")

# Sun
house.penup() 
house.goto(55, 110)
house.fillcolor("yellow")
house.pendown()
house.begin_fill()
house.circle(24)
house.end_fill()
house.write("Sun")

# Sun rays
house.penup()
house.goto(55, 134)
house.pendown()
drawFourRays(house, 25, 24)
house.right(45)
drawFourRays(house, 15, 24)
house.left(45)

# Put down some labels
house.color("pink")
house.penup()
house.goto(-150, 70)
house.pendown()
style = ('Courier', 30, 'italic')
house.write("House", font=style, align='center')
house.penup()
house.goto(150, -150)
house.pendown()
house.write("Tree", font=style, align='center')
#house.write("Tree", None, None, "14pt bold")
house.penup()
house.goto(130, 150)
house.pendown()
house.write("Sun", font=style, align='center')
#house.write("Sun", None, None, "14pt bold")


# Bring the turtle down to the front door, and we're done!
house.penup()
house.goto(-100, -150)
house.left(90)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-367ff3ec6227> in <module>
#      85 house.goto(-120, -130)
#      86 house.pendown()
# ---> 87 writeText(house)
#      88
#      89 # Draw and fill the front of the house
#
# <ipython-input-1-367ff3ec6227> in writeText(tk)
#      79     tk.color('deep pink')
#      80     style = ('Courier', 30, 'italic')
# ---> 81     turtle.write(text, font=style, align='top')
#      82
#      83 #Draw text on top of turtle
#
# C:\conda\lib\turtle.py in write(arg, move, align, font)
#
# C:\conda\lib\turtle.py in write(self, arg, move, align, font)
#    3429             self.undobuffer.push(["seq"])
#    3430             self.undobuffer.cumulate = True
# -> 3431         end = self._write(str(arg), align.lower(), font)
#    3432         if move:
#    3433             x, y = self.pos()
#
# C:\conda\lib\turtle.py in _write(self, txt, align, font)
#    3401         """
#    3402         item, end = self.screen._write(self._position, txt, align, font,
# -> 3403                                                           self._pencolor)
#    3404         self.items.append(item)
#    3405         if self.undobuffer:
#
# C:\conda\lib\turtle.py in _write(self, pos, txt, align, font, pencolor)
#     594         y = y * self.yscale
#     595         anchor = {"left":"sw", "center":"s", "right":"se" }
# --> 596         item = self.cv.create_text(x-1, -y, text = txt, anchor = anchor[align],
#     597                                         fill = pencolor, font = font)
#     598         x0, y0, x1, y1 = self.cv.bbox(item)
#
# KeyError: 'top'
