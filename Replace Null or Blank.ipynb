# %%
import pandas as pd
import numpy as np

# %%
#read data 
data = pd.read_csv('paytm_com-ecommerce_sample.csv', sep=",", encoding='cp1252')

# %%
data
# Out:
#       amtsave                    brand  \
# 0          72                      NaN
# 1         117  Rupa Publications India
# 2          57             Random House
# 3          84    Transworld Publishers
# 4        1050                    Books
# ...       ...                      ...
# 1495      189           HACHETTE INDIA
# 1496     2692       Informa Healthcare
# 1497      250                      NaN
# 1498       49      Pan Macmillan India
# 1499      174                      NaN
#
#                                             breadcrumbs country  \
# 0     Books | Literature & Fiction | Romance | C.J.'...      IN
# 1     Books | Literature & Fiction | Short Stories |...      IN
# 2     Books | Literature & Fiction | Romance | Heart...      IN
# 3     Books | Literature & Fiction | General | Perfe...      IN
# 4     Books | Literature & Fiction | Literature | Pa...      IN
# ...                                                 ...     ...
# ...

# %%
# Select duplicate rows except first occurrence based on all columns
data.replace('', np.nan, inplace=True)
data
# Out:
#       amtsave                    brand  \
# 0          72                      NaN
# 1         117  Rupa Publications India
# 2          57             Random House
# 3          84    Transworld Publishers
# 4        1050                    Books
# ...       ...                      ...
# 1495      189           HACHETTE INDIA
# 1496     2692       Informa Healthcare
# 1497      250                      NaN
# 1498       49      Pan Macmillan India
# 1499      174                      NaN
#
#                                             breadcrumbs country  \
# 0     Books | Literature & Fiction | Romance | C.J.'...      IN
# 1     Books | Literature & Fiction | Short Stories |...      IN
# 2     Books | Literature & Fiction | Romance | Heart...      IN
# 3     Books | Literature & Fiction | General | Perfe...      IN
# 4     Books | Literature & Fiction | Literature | Pa...      IN
# ...                                                 ...     ...
# ...

# %%
#select data wit no duplicates
m  = data[data['brand'].isnull()]
q  = data[data['gallery'].isnull()]
result = pd.concat([m, q], axis=1, join='inner')
result
# Out:
#       amtsave brand                                        breadcrumbs  \
# 0          72   NaN  Books | Literature & Fiction | Romance | C.J.'...
# 13        280   NaN  Books | Literature & Fiction | Others | Flower...
# 16         45   NaN  Books | Literature & Fiction | Literature | Th...
# 32        109   NaN  Books | Literature & Fiction | Others | The 5t...
# 46        128   NaN  Books | Self Help | Motivational & Inspiration...
# ...       ...   ...                                                ...
# 1480       70   NaN  Books | Children & Teens | Children | Activity...
# 1490      364   NaN       Books | Non Fiction | Others | Fade Away : 3
# 1493      364   NaN  Books | Non Fiction | Others | Pop Goes the We...
# 1497      250   NaN  Books | Non Fiction | Others | A Question of B...
# 1499      174   NaN  Books | Non Fiction | Others | THOUSANDS SPLEN...
#
#      country                                               desc discount  \
# ...

# %%
DataWithNoDuplicates.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-639dbd9a352a> in <module>
# ----> 1 DataWithNoDuplicates.tail()
#
# NameError: name 'DataWithNoDuplicates' is not defined
