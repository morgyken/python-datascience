# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Sharktank.csv', sep=",", encoding='cp1252')

# %%
data
# Out:
#                  do       Date    Year        Type    Country  \
# 0        2017.06.11  11-Jun-17  2017.0  Unprovoked  AUSTRALIA
# 1        2017.06.11  11-Jun-17  2017.0  Unprovoked  AUSTRALIA
# 2      2017.06.10.b  10-Jun-17  2017.0  Unprovoked  AUSTRALIA
# 3      2017.06.10.a  10-Jun-17  2017.0  Unprovoked        NaN
# 4      2017.06.10.a  10-Jun-17  2017.0  Unprovoked        NaN
# ...             ...        ...     ...         ...        ...
# 25614           NaN        NaN     NaN         NaN        NaN
# 25615           NaN        NaN     NaN         NaN        NaN
# 25616           NaN        NaN     NaN         NaN        NaN
# 25617           NaN        NaN     NaN         NaN        NaN
# 25618            xx        NaN     NaN         NaN        NaN
#
#                     Area                       Location       Activity  \
# 0      Western Australia       Point Casuarina, Bunbury  Body boarding
# 1      Western Australia       Point Casuarina, Bunbury  Body boarding
# ...

# %%
# Select duplicate rows except first occurrence based on all columns
duplicateRowsDF = data[data.duplicated()]
duplicateRowsDF
# Out:
#                  do       Date    Year        Type    Country  \
# 1        2017.06.11  11-Jun-17  2017.0  Unprovoked  AUSTRALIA
# 4      2017.06.10.a  10-Jun-17  2017.0  Unprovoked        NaN
# 74     2016.10.13.R  13-Oct-16  2016.0     Invalid     MEXICO
# 132      2016.06.14  14-Jun-16  2016.0  Unprovoked        USA
# 201      2015.12.23   7-Nov-15  2015.0     Invalid        NaN
# ...             ...        ...     ...         ...        ...
# 25613           NaN        NaN     NaN         NaN        NaN
# 25614           NaN        NaN     NaN         NaN        NaN
# 25615           NaN        NaN     NaN         NaN        NaN
# 25616           NaN        NaN     NaN         NaN        NaN
# 25617           NaN        NaN     NaN         NaN        NaN
#
#                     Area                                   Location  \
# 1      Western Australia                   Point Casuarina, Bunbury
# 4                Florida                Ponce Inlet, Volusia County
# ...

# %%
#select data wit no duplicates
DataWithNoDuplicates =data.drop_duplicates()
#show the first five data with no duplicates 
DataWithNoDuplicates.head()
# Out:
#              do                  Date    Year        Type         Country  \
# 0    2017.06.11             11-Jun-17  2017.0  Unprovoked       AUSTRALIA
# 2  2017.06.10.b             10-Jun-17  2017.0  Unprovoked       AUSTRALIA
# 3  2017.06.10.a             10-Jun-17  2017.0  Unprovoked             NaN
# 5  2017.06.07.R  Reported 07-Jun-2017  2017.0  Unprovoked  UNITED KINGDOM
# 6    2017.06.04              4-Jun-17  2017.0  Unprovoked             NaN
#
#                 Area                                         Location  \
# 0  Western Australia                         Point Casuarina, Bunbury
# 2           Victoria                    Flinders, Mornington Penisula
# 3            Florida                      Ponce Inlet, Volusia County
# 5        South Devon                                    Bantham Beach
# 6            Florida  Middle Sambo Reef off Boca Chica, Monroe County
#
#         Activity            Name Sex   ... Fatal (Y/N)   Time  \
# ...

# %%
#Output data with no duplicates on csv format
DataWithNoDuplicates.to_csv('Sharktank1.csv',index=False)

# %%
DataWithNoDuplicates.tail()
# Out:
#             do       Date  Year        Type             Country  \
# 6098   ND.0001  1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
# 6099         0        NaN   NaN         NaN                 NaN
# 6106         0        NaN   NaN         NaN                 NaN
# 8598       NaN        NaN   NaN         NaN                 NaN
# 25618       xx        NaN   NaN         NaN                 NaN
#
#                    Area                             Location  Activity  Name  \
# 6098   Eastern Province  Below the English fort, Trincomalee  Swimming  male
# 6099                NaN                                  NaN       NaN   NaN
# 6106                NaN                                  NaN       NaN   NaN
# 8598                NaN                                  NaN       NaN   NaN
# 25618               NaN                                  NaN       NaN   NaN
#
#       Sex   ... Fatal (Y/N) Time Species  Investigator or Source  \
# ...
